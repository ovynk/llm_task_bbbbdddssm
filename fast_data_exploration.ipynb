# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('merged_data_test_task.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1756 entries, 0 to 1755
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Partner                        1756 non-null   object
#  1   Link for whatsapp              0 non-null      float64
#  2   Brand                          1756 non-null   object
#  3   Model                          1756 non-null   object
#  4   full price of car, euro        1755 non-null   float64
#  5   if 1-3 days\ euro per day      1756 non-null   int64
#  6   if 4-6 days\ euro per day      1756 non-null   float64
#  7   if 7-9 days\ euro per day      1756 non-null   float64
#  8   if 10-12 days\ euro per day    1756 non-null   float64
#  9   if 13-15 days\ euro per day    1756 non-null   float64
#  10  if 16-18 days\ euro per day    1756 non-null   float64
#  11  if 19-23 days \ euro per day   1756 non-null   float64
# ...

# %%
data.nunique()
# Out:
# Partner                            80
# Link for whatsapp                   0
# Brand                              76
# Model                            1031
# full price of car, euro            92
# if 1-3 days\ euro per day          93
# if 4-6 days\ euro per day          93
# if 7-9 days\ euro per day          93
# if 10-12 days\ euro per day        93
# if 13-15 days\ euro per day        93
# if 16-18 days\ euro per day        93
# if 19-23 days \ euro per day       93
# if 24-31 days\ euro per day        93
# Additional info about car           0
# Locations                          50
# Contact person                     52
# link                               61
# Fleet                              67
# Company details                    52
# Reiting of trusting                 5
# Reiting of speed                    6
# Reiting of quality of servise       6
# dtype: int64

# %%
data.describe()
# Out:
#        Link for whatsapp  full price of car, euro  if 1-3 days\ euro per day  \
# count                0.0             1.755000e+03                1756.000000
# mean                 NaN             1.753021e+05                 876.011390
# std                  NaN             1.467165e+05                 733.671683
# min                  NaN             4.000000e+04                   0.000000
# 25%                  NaN             8.000000e+04                 400.000000
# 50%                  NaN             1.220000e+05                 610.000000
# 75%                  NaN             2.500000e+05                1250.000000
# max                  NaN             3.600000e+06               18000.000000
#
#        if 4-6 days\ euro per day  if 7-9 days\ euro per day  \
# count                1756.000000                1756.000000
# mean                  814.690592                 753.369795
# std                   682.314665                 630.957648
# ...

# %%
data.head(50)
# Out:
#               Partner  Link for whatsapp                Brand  \
# 0            Mr Good1                NaN          Range Rover
# 1            Mr Good1                NaN          Range Rover
# 2            Mr Good1                NaN                 Audi
# 3            Mr Good1                NaN                 Audi
# 4            Mr Good1                NaN             Mercedes
# 5            Mr Good1                NaN             Mercedes
# 6            Mr Good1                NaN             Mercedes
# 7            Mr Good1                NaN             Mercedes
# 8            Mr Good1                NaN             Mercedes
# 9            Mr Good1                NaN              Porsche
# 10           Mr Good1                NaN                 Mini
# 11           Mr Good1                NaN             Mercedes
# 12           Mr Good1                NaN         Aston Martin
# 13           Mr Good1                NaN              Porsche
# ...
